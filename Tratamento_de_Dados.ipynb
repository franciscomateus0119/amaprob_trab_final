# %% [markdown]
# Mossoró, 18 de janeiro de 2025.
#
# Notebook para montagem do Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dolar Diário
#
# Fonte:

# %%
'''
X_train -> Data t
y_train -> Cotação (Último) passada

X_test -> Data t+1
y_test -> Cotação (Último) prevista
'''
# Out:
# '\nX_train -> Data t\ny_train -> Cotação (Último) passada\n\nX_test -> Data t+1\ny_test -> Cotação (Último) prevista\n'

# %%
# Ler arquivo /content/drive/MyDrive/Dolar/DadosBrutos/USD_BRL Dados Históricos (2).csv
df_dolar_diario = pd.read_csv('./DadosBrutos/USD_BRL Dados Históricos (2).csv')

# %%
df_dolar_diario
# Out:
#            Data  Último Abertura  Máxima  Mínima     Vol.    Var%
# 0    17.01.2025  6,0704   6,0551  6,0905  6,0266      NaN   0,34%
# 1    16.01.2025  6,0499   6,0104  6,0708  5,9935      NaN   0,67%
# 2    15.01.2025  6,0098   6,0560  6,0701  6,0043      NaN  -0,76%
# 3    14.01.2025  6,0559   6,0979  6,0979  6,0406      NaN  -0,63%
# 4    13.01.2025  6,0944   6,1099  6,1358  6,0748      NaN  -0,18%
# ..          ...     ...      ...     ...     ...      ...     ...
# 530  06.01.2023  5,2254   5,3514  5,3697  5,2186  154,80K  -2,35%
# 531  05.01.2023  5,3509   5,4315  5,4315  5,3478  148,32K  -1,48%
# 532  04.01.2023  5,4312   5,4799  5,4799  5,4248  175,09K  -0,89%
# 533  03.01.2023  5,4797   5,3638  5,4802  5,3396  188,23K   2,17%
# 534  02.01.2023  5,3633   5,2865  5,3671  5,2861   84,04K   1,46%
#
# [535 rows x 7 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_dolar_diario.index, df_dolar_diario['Último'])
plt.xlabel('Data')
plt.ylabel('Cotação')
plt.title('Evolução da Cotação do Dólar')
plt.show()

# %%
df_dolar_diario = pd.read_csv('./DadosBrutos/Cotação do Dólar por período.csv')
df_dolar_diario
# Out:
#      cotacaoCompra cotacaoVenda          dataHoraCotacao
# 0           2,6923       2,6929  2015-01-02 13:09:00.008
# 1           2,7101       2,7107  2015-01-05 13:05:39.045
# 2           2,7016       2,7023  2015-01-06 13:02:40.508
# 3           2,6801       2,6807  2015-01-07 13:03:26.355
# 4           2,6913       2,6919  2015-01-08 13:14:50.913
# ...            ...          ...                      ...
# 2503        6,1527       6,1541  2024-12-24 11:10:05.681
# 2504         6,165       6,1656  2024-12-26 13:09:30.003
# 2505        6,1985       6,1991  2024-12-27 13:03:30.393
# 2506        6,1917       6,1923  2024-12-30 13:06:26.618
# 2507        6,1917       6,1923  2024-12-31 10:04:09.264
#
# [2508 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(df_dolar_diario['cotacaoCompra'])
plt.xlabel('Data')
plt.ylabel('Cotação')
plt.title('Evolução da Cotação do Dólar')
plt.show()
